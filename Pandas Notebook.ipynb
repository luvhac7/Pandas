# %%
import pandas as pd
#two main type:dataframes or series
#csv->commas seprated files
df=pd.read_csv("orders.csv")
print(df)
#pandas is open-source library desined for data manupulation and analysis.it makes working with stuctured data fast,flexible,and intutive especially if we are dealing wih csv files ,excel sheets sql tables json or apis
#two core datastructure of pandas are: series and dataframes
#series:-1D labeled array (like coloums)
#dataframes :- 2D labelled datastructres (like full spreadsheet /sQl tables)
#dataframes :2 Demsional tabular data with labelled rows and coloums
#dataframes: key features:
#label -based indexing
#coloum-wise and row-wise operations
#support for mixed data types
#fast ,vectorized operations (built on numpy)


df.head()#give first  dataframes from whole dataset
df.tail()#give last 5 dataframes form whole dataset
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.info()#gives the info about the dataframes
df.describe()#descritopptive statictics summarize central tendancy,dispersion and shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     object
#  2   Product       40 non-null     object
#  3   Category      40 non-null     object
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     object
#  7   Shipped       40 non-null     object
#  8   Country       40 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.9+ KB
#            OrderID    Quantity        Price
# count    40.000000   40.000000    40.000000
# mean   1020.500000    5.450000   106.457500
# std      11.690452   15.903475   201.091854
# min    1001.000000    1.000000     0.800000
# 25%    1010.750000    1.000000    18.000000
# 50%    1020.500000    1.000000    43.500000
# ...

# %%
df.columns #gives all coloums
df.index #first step to know dataset
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
df[["Country","Product"]]
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
df.iloc[10]["df.head"]
# Out:
# 'France'

# %%
df[(df["Category"]=="Electronics" )& (df["Country"]=="USA")]
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
df[(df["Category"]=="Electronics" )| (df["Country"]=="USA")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 0      1001        John Smith             Laptop  Electronics         1
# 1      1002         Sarah Lee         Headphones  Electronics         2
# 4      1005     Carlos Mendez           Keyboard  Electronics         2
# 7      1008        James Park            Monitor  Electronics         2
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 10     1011     Sophie Martin             Webcam  Electronics         1
# 13     1014   Diego Rodriguez          USB Drive  Electronics         5
# 16     1017     Anna Kowalski     Wireless Mouse  Electronics         2
# 17     1018     Michael Brown     Desk Organizer    Furniture         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 24     1025    Lucas Anderson       Tablet Stand  Electronics         1
# ...

# %%
df[df["Quantity"]!=2]
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 12     1013       Emma Wilson                Stapler   Stationery         3
# 13     1014   Diego Rodriguez              USB Drive  Electronics         5
# 14     1015         Lisa Chen              Bookshelf    Furniture         1
# ...

# %%
df[df["CustomerName"].str.endswith("a")]
# Out:
#     OrderID      CustomerName            Product     Category  Quantity  \
# 9      1010  Takeshi Nakamura              Mouse  Electronics         1
# 18     1019       Yuki Tanaka         Calculator  Electronics         1
# 19     1020   Fatima Al-Zahra         Whiteboard    Furniture         1
# 21     1022    Isabella Silva  Bluetooth Speaker  Electronics         1
# 39     1040      Anna Ivanova         Desk Clock    Furniture         1
#
#     Price   OrderDate Shipped       Country
# 9    35.0  2024-06-11     Yes         Japan
# 18   15.0  2024-06-20     Yes         Japan
# 19  120.0  2024-06-21     Yes  Saudi Arabia
# 21   95.0  2024-06-23     Yes        Brazil
# 39   35.0  2024-07-11     Yes       Ukraine

# %%
df[df["Country"].isin(["USA","Sweden","Brazil"])]
# Out:
#     OrderID    CustomerName            Product     Category  Quantity   Price  \
# 0      1001      John Smith             Laptop  Electronics         1  1200.0
# 17     1018   Michael Brown     Desk Organizer    Furniture         1    65.0
# 21     1022  Isabella Silva  Bluetooth Speaker  Electronics         1    95.0
# 24     1025  Lucas Anderson       Tablet Stand  Electronics         1    28.0
# 33     1034    Alex Johnson        Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 17  2024-06-19      No     USA
# 21  2024-06-23     Yes  Brazil
# 24  2024-06-26     Yes  Sweden
# 33  2024-07-05     Yes     USA

# %%
#reverse
df[~df["Country"].isin(["USA","Sweden","Brazil"])]
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 11     1012         Raj Patel           File Cabinet    Furniture         2
# ...

# %%
#udpate data
df.loc[df["CustomerName"]=="Anna Ivanova","Products"]="Trim"

# %%
df.loc[df["CustomerName"]=="Anna Ivanova","Products"]
# Out:
# 39    Trim
# Name: Products, dtype: object

# %%
df.loc[df["Country"]=="USA","United States"]="United Sattes"

# %%
df.loc[df["Country"]=="USA"]
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country Products  United States
# 0   2024-06-01     Yes     USA      NaN  United Sattes
# 17  2024-06-19      No     USA      NaN  United Sattes
# 33  2024-07-05     Yes     USA      NaN  United Sattes

# %%
df["Country"]=df["Country"].str.upper()

# %%
df["Country"]
# Out:
# 0              USA
# 1           CANADA
# 2              UAE
# 3        SINGAPORE
# 4           MEXICO
# 5              UAE
# 6               UK
# 7      SOUTH KOREA
# 8            ITALY
# 9            JAPAN
# 10          FRANCE
# 11           INDIA
# 12       AUSTRALIA
# 13           SPAIN
# 14           CHINA
# 15           EGYPT
# 16          POLAND
# 17             USA
# 18           JAPAN
# 19    SAUDI ARABIA
# 20          CANADA
# 21          BRAZIL
# 22         GERMANY
# 23        PAKISTAN
# 24          SWEDEN
# 25          FRANCE
# 26       ARGENTINA
# 27          RUSSIA
# 28     SOUTH KOREA
# 29           ITALY
# 30         MOROCCO
# 31         GERMANY
# 32        COLOMBIA
# 33             USA
# 34           JAPAN
# 35              UK
# 36        PORTUGAL
# 37            IRAN
# 38     SOUTH KOREA
# 39         UKRAINE
# Name: Country, dtype: object

# %%
df=df.drop(39)

# %%
print(df)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.dropna()#remove null value
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerName, Product, Category, Quantity, Price, OrderDate, Shipped, Country, Products, United States]
# Index: []

# %%
df.fillna({"OrderID":0},inplace=True)

# %%
df.rename(columns={"OrderID":"Order ID"},inplace=True)

# %%
print(df)
# Out:
#     Order ID      CustomerName                Product     Category  Quantity  \
# 0       1001        John Smith                 Laptop  Electronics         1
# 1       1002         Sarah Lee             Headphones  Electronics         2
# 2       1003          Ali Khan           Office Chair    Furniture         1
# 3       1004        Alice Wong              Desk Lamp    Furniture         3
# 4       1005     Carlos Mendez               Keyboard  Electronics         2
# 5       1006      Nora Ibrahim               Notebook   Stationery         5
# 6       1007       Emily Davis          Standing Desk    Furniture         1
# 7       1008        James Park                Monitor  Electronics         2
# 8       1009       Maria Rossi                    Pen   Stationery        10
# 9       1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10      1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
#analze data

df["Country"].value_counts()
#count
# Out:
# Country
# USA             3
# JAPAN           3
# SOUTH KOREA     3
# UAE             2
# CANADA          2
# ITALY           2
# UK              2
# FRANCE          2
# GERMANY         2
# SINGAPORE       1
# MEXICO          1
# INDIA           1
# AUSTRALIA       1
# CHINA           1
# SPAIN           1
# EGYPT           1
# POLAND          1
# SAUDI ARABIA    1
# BRAZIL          1
# PAKISTAN        1
# SWEDEN          1
# ARGENTINA       1
# RUSSIA          1
# MOROCCO         1
# COLOMBIA        1
# PORTUGAL        1
# IRAN            1
# Name: count, dtype: int64

# %%
df.groupby("Country")["Price"].sum()
# Out:
# Country
# ARGENTINA         22.0
# AUSTRALIA         12.0
# BRAZIL            95.0
# CANADA           153.5
# CHINA            280.0
# COLOMBIA          42.0
# EGYPT              8.0
# FRANCE           160.0
# GERMANY          175.0
# INDIA            180.0
# IRAN              28.0
# ITALY             19.5
# JAPAN            105.0
# MEXICO            80.0
# MOROCCO           32.0
# PAKISTAN           4.0
# POLAND            45.0
# PORTUGAL         125.0
# RUSSIA             2.5
# SAUDI ARABIA     120.0
# SINGAPORE         45.0
# SOUTH KOREA      348.0
# SPAIN             25.0
# SWEDEN            28.0
# UAE              305.0
# UK               518.0
# USA             1265.8
# Name: Price, dtype: float64

# %%
df.sort_values("Price",ascending=False)
# Out:
#     Order ID      CustomerName                Product     Category  Quantity  \
# 0       1001        John Smith                 Laptop  Electronics         1
# 6       1007       Emily Davis          Standing Desk    Furniture         1
# 2       1003          Ali Khan           Office Chair    Furniture         1
# 14      1015         Lisa Chen              Bookshelf    Furniture         1
# 7       1008        James Park                Monitor  Electronics         2
# 11      1012         Raj Patel           File Cabinet    Furniture         2
# 1       1002         Sarah Lee             Headphones  Electronics         2
# 31      1032     Thomas Müller       Document Scanner  Electronics         1
# 36      1037     Carlos Santos       Wireless Earbuds  Electronics         1
# 19      1020   Fatima Al-Zahra             Whiteboard    Furniture         1
# 28      1029      Seo-yeon Kim      Wireless Keyboard  Electronics         1
# ...

# %%
#modififacation to dataframe
df.to_csv("new_file.csv",index=False)

# %%
x=pd.read_csv("new_file.csv")
print(x)
# Out:
#     Order ID      CustomerName                Product     Category  Quantity  \
# 0       1001        John Smith                 Laptop  Electronics         1
# 1       1002         Sarah Lee             Headphones  Electronics         2
# 2       1003          Ali Khan           Office Chair    Furniture         1
# 3       1004        Alice Wong              Desk Lamp    Furniture         3
# 4       1005     Carlos Mendez               Keyboard  Electronics         2
# 5       1006      Nora Ibrahim               Notebook   Stationery         5
# 6       1007       Emily Davis          Standing Desk    Furniture         1
# 7       1008        James Park                Monitor  Electronics         2
# 8       1009       Maria Rossi                    Pen   Stationery        10
# 9       1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10      1011     Sophie Martin                 Webcam  Electronics         1
# ...
